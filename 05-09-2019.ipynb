# %% [markdown]
# # markdown introduction

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*

# %% [markdown]
# <strike>striked text</strike><br/>
# 'hhighlighted text'

# %% [markdown]
# <image src="https://www.bing.com/images/search?view=detailV2&ccid=3FOr%2fo9y&id=D0EEEF45483C5C71742B1397A21A189195183A82&thid=OIP.3FOr_o9ypPara98tOHfmYAHaHa&mediaurl=https%3a%2f%2folimex.files.wordpress.com%2f2014%2f06%2fpython_sh-600x6001.png&exph=600&expw=600&q=python+programming+images&simid=608015773067382558&selectedIndex=11">

# %% [markdown]
# <img src="https://www.bing.com/images/search?view=detailV2&ccid=3FOr%2fo9y&id=D0EEEF45483C5C71742B1397A21A189195183A82&thid=OIP.3FOr_o9ypPara98tOHfmYAHaHa&mediaurl=https%3a%2f%2folimex.files.wordpress.com%2f2014%2f06%2fpython_sh-600x6001.png&exph=600&expw=600&q=python+programming+images&simid=608015773067382558&selectedIndex=11">

# %% [markdown]
# <img src="https://www.bing.com/images/search?view=detailV2&ccid=VumukdzN&id=0973892DF88D5923D60DAA9AA852B5F7A7031960&thid=OIP.VumukdzNJrCukyozELC6MwHaFN&mediaurl=http%3a%2f%2fwww.sryitsolutions.com%2fwp-content%2fuploads%2f2016%2f11%2fPython_Programming.jpeg&exph=263&expw=374&q=python+programming+images&simid=608003785773156940&selectedIndex=10">

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%html
# <iframe width="727" height="409" src="https://www.youtube.com/embed/rfscVS0vtbw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="727" height="409" src="https://www.youtube.com/embed/rfscVS0vtbw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# *python
# *java
# *R programming
# *scripiting language
# -html
# -css
# -xml

# %% [markdown]
# * python
# * java
# * R programming
# * scripting language
# - html
# - css
# - xml

# %%
print("hello world")
print("apssdc")
# Out:
# hello world
# apssdc

# %%
print(1)
# Out:
# 1

# %% [markdown]
# * Arthematic operators
# * Relational operators
# * Assignment operators
# * Bitwise operators
# * Identity operators
# * Membership operators

# %% [markdown]
# ### Arthematic operator

# %%
print(10)
# Out:
# 10

# %%
print(2+3)
# Out:
# 5

# %%
print(3*6)
# Out:
# 18

# %%
print(9-6)
# Out:
# 3

# %%
type(1)
# Out:
# int

# %%
type(18/3)
# Out:
# float

# %%
type(10//3)
# Out:
# int

# %%
10/5
# Out:
# 2.0

# %%
2**4
# Out:
# 16

# %%
print(2,4)
# Out:
# 2 4

# %%
pow(2,4)
# Out:
# 16

# %%
10%3
# Out:
# 1

# %% [markdown]
# ###  Logical operators

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### Relational operators

# %%
2 == 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 < 10
# Out:
# True

# %%
10 > 20
# Out:
# False

# %% [markdown]
# ### Assignment operastors

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a="hello"
type(a)
# Out:
# str

# %%
a=b=c=10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
a="susmi"

# %%
a
# Out:
# 'susmi'

# %%
a,b,c,=1,2,3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a
b
c
# Out:
# 3

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a,b=b,a

# %%
a,b
# Out:
# (2, 1)

# %%
a=1
a
# Out:
# 1

# %%
a++ #it is not supported in python
# Out:
#   File "<ipython-input-46-c828489c4eb6>", line 1
#     a++
#         ^
# SyntaxError: invalid syntax

# %%
a=  a + 1
a
# Out:
# 2

# %%
a+=1

# %%
a
# Out:
# 3

# %%
a *= 20

# %%
a
# Out:
# 60

# %%
a //= 4

# %%
a
# Out:
# 15

# %% [markdown]
# ### Bitwise operators

# %%
4 & 7
# Out:
# 4

# %%
7 | 4
# Out:
# 7

# %%
8 << 2
# Out:
# 32

# %%
8 >> 2
# Out:
# 2

# %% [markdown]
# ### Identity operators

# %%
2 == 3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# ### Membeship operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"Ap" in "apssdc"
# Out:
# False

# %%
"T" not in "apssdc"
# Out:
# True
